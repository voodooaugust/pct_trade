# %%
#importing necessary data files
# %matplotlib inline
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
def PDTable(importedTable):
    return trialData()

def trialData():
    
    return pd.read_csv("../tmp/0175.HK.csv",index_col=0)
    

def volTrade(Table):
    table = pd.DataFrame(Table)
    df = table['Volumne'].cumsum()
    print df
    
if __name__ == "__main__":
    volTrade(trialData())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-31fb944bff6b> in <module>()
#      13
#      14 if __name__ == "__main__":
# ---> 15     volTrade(trialData())
#      16
#      17
#
# <ipython-input-41-31fb944bff6b> in volTrade(Table)
#       9 def volTrade(Table):
#      10     table = pd.DataFrame(Table)
# ---> 11     df = table['Volumne'].cumsum()
#      12     print df
#      13
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
#    2071         # duplicate columns & possible reduce dimensionality
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1532         res = cache.get(item)
#    1533         if res is None:
# -> 1534             values = self._data.get(item)
#    1535             res = self._box_item_values(item, values)
#    1536             cache[item] = res
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
# -> 2395                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2396
#    2397         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5239)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5085)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20405)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20359)()
#
# KeyError: 'Volumne'

# %%
df = trialData()
r = df['Volume'][-100:]
r.cumsum().plot()



plt.figure()

# %% [raw]
# attr = {
#     "s": "Symbol",
#     "v': "Volumn",
#     "k": "52 Week High",
#     "k1": "Last Trade (Realtime) With Time",
#     "k2": "Change Percent (Realtime)",
#     "k3": "Last Trade Size",
#     "k4": "Change From 52 week High"
#     "k5": "Percent Change From 52 week High"
# }
#
#     #["noname", ["d2", "Trade Date"]],
#     #["noname", ["c6", "Change (Realtime)"]],
#     #["noname", ["t1", "Last Trade Time"]],
#
#     #["noname", ["p2", "Change in Percent"]],
#     #["noname", ["c8", "After Hours Change (Realtime)"]],
#     #["noname", ["m5", "Change From 200 Day Moving Average"]],
#     #["noname", ["c3", "Commission"]],
#     #["noname", ["m6", "Percent Change From 200 Day Moving Average"]],
#     #["noname", ["g", "Day’s Low"]],
#     #["noname", ["m7", "Change From 50 Day Moving Average"]],
#     #["noname", ["h", "Day’s High"]],
#     #["noname", ["m8", "Percent Change From 50 Day Moving Average"]],
#
#     #["noname", ["m3", "50 Day Moving Average"]],
#     #["noname", ["l", "Last Trade (With Time)"]],
#     #["noname", ["m4", "200 Day Moving Average"]],
#     #["noname", ["l1", "Last Trade (Price Only)"]],
#     #["noname", ["t8", "1 yr Target Price"]],
#     #["noname", ["w1", "Day’s Value Change"]],
#     #["noname", ["g1", "Holdings Gain Percent"]],
#     #["noname", ["w4", "Day’s Value Change (Realtime)"]],
#     #["noname", ["g3", "Annualized Gain"]],
#     #["noname", ["p1", "Price Paid"]],
#     #["noname", ["g4", "Holdings Gain"]],
#     #["noname", ["m", "Day’s Range"]],
#     #["noname", ["g5", "Holdings Gain Percent (Realtime)"]],
#     #["noname", ["m2", "Day’s Range (Realtime)"]],
#     #["noname", ["g6", "Holdings Gain (Realtime)"]],
#
#     #["noname", ["v", "Volumn"]],
#     #["noname", ["j", "52 week Low"]],
#     #["noname", ["j1", "Market Capitalization"]],
#     #["noname", ["j5", "Change From 52 Week Low"]],
#     #["noname", ["j3", "Market Cap (Realtime)"]],
#
#     #["noname", ["f6", "Float Shares"]],
#     #["noname", ["j6", "Percent Change From 52 week Low"]],
#     ["name", ["n", "Company Name"]],
#
#     #["noname", ["n4", "Notes"]],
#     #["noname", ["w", "52 week Range"]],
#     #["noname", ["s1", "Shares Owned"]],
#     #["noname", ["x", "Stock Exchange"]],
#     #["noname", ["j2", "Shares Outstanding"]],
#     #["noname", ["v", "Volume"]],
#     #["noname", ["a5", "Ask Size"]],
#     #["noname", ["b6", "Bid Size"]],
#
#     #["noname", ["t7", "Ticker Trend"]],
#     #["noname", ["a2", "Average Daily Volume"]],
#     #["noname", ["t6", "Trade Links"]],
#     #["noname", ["i5", "Order Book (Realtime)"]],
#     #["noname", ["l2", "High Limit"]],
#     #["noname", ["e", "Earnings per Share"]],
#     #["noname", ["l3", "Low Limit"]],
#     #["noname", ["e7", "EPS Estimate Current Year"]],
#     #["noname", ["v1", "Holdings Value"]],
#     #["noname", ["e8", "EPS Estimate Next Year"]],
#     #["noname", ["v7", "Holdings Value (Realtime)"]],
#     #["noname", ["e9", "EPS Estimate Next Quarter"]],
#     #["noname", ["s6", "evenue"]],
#     #["noname", ["b4", "Book Value"]],
#     #["noname", ["j4", "EBITDA"]],
#     #["noname", ["p5", "Price / Sales"]],
#     #["noname", ["p6", "Price / Book"]],
#     #["noname", ["r", "P/E Ratio"]],
#     #["noname", ["r2", "P/E Ratio (Realtime)"]],
#     #["noname", ["r5", "PEG Ratio"]],
#     #["noname", ["r6", "Price / EPS Estimate Current Year"]],
#     #["noname", ["r7", "Price / EPS Estimate Next Year"]],
#     #["noname", ["s7", "Short Ratio"]]

# %%
# Hello World program in Python
# %matplotlib inline
    
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import urllib
import tempfile as tp
import os
from datetime import datetime

matplotlib.style.use('ggplot')

        
def downloadfile2(stock, f = 'sd1t1vml1c1p2k4k5a2'):

  
    baseurl = 'http://finance.yahoo.com/d/quotes.csv?%s'
    stock = ['{:0>4}'.format(x) + '.HK' for x in stock]
    s = '+'.join(stock)
  
    paras = urllib.urlencode({'s': s, 'f': f})
    f = urllib.urlopen(baseurl % paras)
     
    # sd1t1vml1c1p2k4k5a2
    colname = ['symbol', 'date', 'time', 'volume', 
               'daily_rng', 'last_price', 
               'change', 'change_pct', '52wH', '52wH_pct', 'avg_vol']
    data = pd.read_csv(f, names=colname)  
    data = data.set_index(['symbol']) 
    
    f.close()
    return data 


    # construct multiIndex
    
    
        
    # store data
    """
    
    home = os.path.dirname(os.getcwd())
    datahome = os.path.join(home, 'data')
    
    timestr = datetime.strftime(datetime.now(), '%D%H%M')
    data.to_csv(os.path.join(datahome, timestr + '.csv'), index=False)
    """

def datapanel():
    pass

    

def getStocklist():
    home = os.path.dirname(os.getcwd())
    ls = os.path.join(home, 'data', 'stock_list.xls')
    ls = pd.read_excel(ls)
    return ls


def a2():
    ls = getStocklist()
    downloadfile2(ls[0])
    
    
ls = getStocklist()
code = ['1398', '939', '1']


d = pd.DataFrame()
for x in range(15):
    code = list(ls['STOCK CODE'][x*100:(x+1)*100])
    data = downloadfile2(code)
#     print data
    d = d.append(data)
# 2383.HK     -0.52%  -0.350   -15.42%    432320.0
# 2386.HK     -1.95%  -1.050   -12.24%   4299890.0
# 2388.HK     +0.86%  -0.350    -0.99%   9515830.0
# 2389.HK     +0.00%  -0.080   -13.33%  12771300.0
# 2393.HK     +1.06%  -0.790   -17.17%   2783290.0
# 2398.HK     -2.10%  -0.070    -2.92%     86145.0
# 2399.HK     +0.39%  -3.940   -43.58%   1090940.0
#
# [1461 rows x 10 columns]

# %%
import httplib

con = httplib.HTTPconnection('http://finance.yahoo.com/d/quotes.csv?')
res = con.getresponse()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-62-e68a31776e2d> in <module>()
#       1 import httplib
#       2
# ----> 3 con = httplib.HTTPconnection('http://finance.yahoo.com/d/quotes.csv?')
#       4 res = con.getresponse()
#
# AttributeError: 'module' object has no attribute 'HTTPconnection'

# %%
import os
print os.getcwd()
print os.path.basename(os.getcwd())
home = os.path.dirname(os.getcwd())
print os.path.join(home, 'data', 'sotcklist.xls')

print os.path.split(os.getcwd())



from datetime import datetime

timestr = datetime.strftime(datetime.now(), '%H%M')
# Out:
# C:\Users\fbuser\Desktop\august\git\doc\pct_trade\bin
# bin
# C:\Users\fbuser\Desktop\august\git\doc\pct_trade\data\sotcklist.xls
# ('C:\\Users\\fbuser\\Desktop\\august\\git\\doc\\pct_trade', 'bin')
# '1055'

# %%
        
def a():        
    code = []
    file = pd.read_csv(c,index_col=0)
    vol = file['Volume'] / 1000000 / file['Close']
    
    print vol.size

    ma = vol.rolling(14).mean().dropna()
    plt.figure()
    plt.subplot(212)
    plt.plot_date(vol.index, vol, ls='-', fmt="r-", c='b')
    plt.plot_date(ma.index, ma, ls='-', fmt="r-")


    c = vol.cumsum()
    slope = (c[-1] - c[0]) / vol.size
    l = [int(round(slope * x, -1)) for x in range(vol.size)]

    plt.subplot(211)
    plt.plot_date(vol.index, l, fmt="r-", c='b')
    plt.plot_date(c.index, c, fmt="r-")
# Out:
# IOErrorTraceback (most recent call last)
# <ipython-input-7-52971c2da324> in <module>()
#      75
#      76 codeset = list(ls['STOCK CODE'][1200:])
# ---> 77 downloadfile2(codeset)
#      78
#      79
#
# <ipython-input-7-52971c2da324> in downloadfile2(stock, f)
#      29
#      30     paras = urllib.urlencode({'s': s, 'f': f})
# ---> 31     f = urllib.urlopen(baseurl % paras)
#      32
#      33     # sd1t1vml1c1p2k4k5a2
#
# C:\Users\fbuser\Anaconda2\lib\urllib.pyc in urlopen(url, data, proxies, context)
#      85         opener = _urlopener
#      86     if data is None:
# ---> 87         return opener.open(url)
#      88     else:
#      89         return opener.open(url, data)
#
# C:\Users\fbuser\Anaconda2\lib\urllib.pyc in open(self, fullurl, data)
#     211         try:
#     212             if data is None:
# --> 213                 return getattr(self, name)(url)
#     214             else:
#     215                 return getattr(self, name)(url, data)
#
# C:\Users\fbuser\Anaconda2\lib\urllib.pyc in open_http(self, url, data)
#     355             # something went wrong with the HTTP status line
#     356             raise IOError, ('http protocol error', 0,
# --> 357                             'got a bad status line', None)
#     358         # According to RFC 2616, "2xx" code indicates that the client's
#     359         # request was successfully received, understood, and accepted.
#
# IOError: ('http protocol error', 0, 'got a bad status line', None)
